# %% [markdown]
# # Runtime Comparisons on Multi-Dimensional Isotropic Gaussian Data.

# %%
import algorithms
import linear_regression
from linear_regression import LinearRegression

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import copy
import scipy.linalg
import gurobipy as gp
from gurobipy import GRB
import sys
import itertools

# %% [markdown]
# ## Set Random Seed.

# %%
np.random.seed(0)

# %% [markdown]
# ## Data Generation (following section 5.1, MR23).

# %%
# Set dimensions.
total_observations = 75000 # 16500
d = 2

# Generate X, a d-dimensional isotropic Gaussian.
mean = np.zeros(d)
cov = np.identity(d)
x = np.random.multivariate_normal(mean, cov, total_observations)

# Generate Y, a linear combination of x with some noise.
sigma = 1
epsilon = np.random.normal(0, sigma, total_observations)
y = []
# take the inner product of x and beta and add the epsilon.
for i in range(total_observations):
    y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
y = np.array(y)

# %% [markdown]
# ## Plot Data.

# %%
plt.figure(figsize=(9, 7))

plt.scatter(x[:, 1], y, marker='o', color='black', s=56)

plt.xlabel('x', fontsize=26) 
plt.ylabel('y', fontsize=26)
plt.xticks(fontsize=22) 
plt.yticks(fontsize=22)
plt.legend(fontsize=22)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Model Fitting
#
# Fit the data using OLS regression.

# %%
lr = LinearRegression(x=x.T, y=y)
lr.fit()
print(
    f"Estimated beta1 with full dataset: {lr.beta[1]}\n"
)
# Out:
# Estimated beta1 with full dataset: 0.9997269103818985

# %% [markdown]
# ## Net Approx. Algorithm

# %%
# the NetApprox algorithm of MR22.
# 

'''
For fixed lambda, compute maximum weight of any weight vector w
that has lambda in OLS(X,y,w)
'''
def solve_fixed_lambda(X,XR,lam):
    n = X.shape[0]
    d = X.shape[1]
    c = -np.ones((n))
    A_eq = np.zeros((d,n))
    b_eq = np.zeros((d))
    for i in range(d):
        A_eq[i] = (X.T)[i] * (XR@lam)
    m = gp.Model("net-model")
    m.Params.OutputFlag = 0
    w = m.addMVar(shape=n,vtype=GRB.CONTINUOUS,name="w",lb=0,ub=1)
    m.setObjective(c @ w, GRB.MINIMIZE)
    m.addConstr(A_eq @ w == b_eq)
    m.optimize()
    return w.X

'''
NET UPPER BOUND

Input:
- X: n x d (covariate matrix)
- y: n (response vector)
- trials: integer

Output:
- Net upper bound on Stability(X,y)
'''
def net_algorithm(X,y,trials):
    n = X.shape[0]
    d = X.shape[1]
    XR = np.zeros((d,n))
    for i in range(d-1):
        XR[i] = (X.T)[i+1]
    XR[d-1] = y
    XR = XR.T
    assert(np.linalg.matrix_rank(XR)==d)
    U,s,Vh = scipy.linalg.svd(XR, full_matrices=False)
    A = Vh.T @ np.diag(1.0/s) @ np.eye(d)
    wstar = np.zeros((n))
    for i in range(trials):
        v = np.random.multivariate_normal(np.zeros((d)),np.eye(d))
        v = v / np.linalg.norm(v)
        lam = A@v
        w = solve_fixed_lambda(X,XR,lam)
        if sum(w) > sum(wstar):
            wstar = w
    return n-sum(wstar), wstar

# %%
start_time = time.time()
n_sumwstar, wstar = net_algorithm(x,y,1000)
end_time = time.time()
print(f"N = {total_observations}, d = {d}, Stability = {n_sumwstar}, Time = {end_time - start_time}")
# Feb 12th: >10 min (for N=5000, d=200)
# Feb 12th: 3.42 min (for N=5000, d=50)
# Out:
# N = 5000, d = 50, Stability = 3885.5045820814644, Time = 222.56035995483398

# %%
print(f"Number of points needed to be removed to zero-out the OLS solution: {n_sumwstar}")
# find the indice of wstar that are non-one.
mis_inds = np.where(wstar != 1)[0]
# Out:
# Number of points needed to be removed to zero-out the OLS solution: 446.69883783722213

# %% [markdown]
# ## Recreating Figure 2 of MR23.

# %%
list_of_noise = [0.1, 0.5, 1, 2, 5, 10]
weights_removed = []
for noise_var in list_of_noise:
    # Generate Y, a linear combination of x with some noise.
    sigma = noise_var
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add the epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)
    n_sumwstar, wstar = net_algorithm(x,y,10**3)
    weights_removed.append(n_sumwstar)

# %%
# create a scatter plot of the noise variance and the number of weights removed.
plt.figure(figsize=(9, 7))
plt.scatter(list_of_noise, weights_removed, marker='o', color='blue', s=56)
plt.plot(list_of_noise, weights_removed, color='blue')

plt.xscale('log')
plt.xlabel('Variance', fontsize=26)
plt.ylabel('Sample Weight Removed', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.show()

# %% [markdown]
# ## Test Runtime against Dimension.

# %%
# Record runtime.
NetApprox_times = []
# Set dimensions.
# dimension_list = [2, 5, 10, 20, 50, 100, 200, 499]
dimension_list = [2, 5, 10, 25, 50]
total_observations = 75000
for dim in dimension_list:
    d = dim
    # Generate X, a d-dimensional isotropic Gaussian.
    mean = np.zeros(d)
    cov = np.identity(d)
    x = np.random.multivariate_normal(mean, cov, total_observations)
    print(f'shape of x {x.shape}.')
    # Generate Y, a linear combination of x with some noise.
    sigma = 1
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add the epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)

    # start recording time.
    start_time = time.time()
    n_sumwstar, wstar = net_algorithm(x,y,1000)
    # end recording time.
    end_time = time.time()
    NetApprox_times.append(end_time - start_time)
    print("done dimension: ", d, "time: ", end_time - start_time)
# Out:
# shape of x (75000, 2).
# done dimension:  2 time:  354.3781728744507
# shape of x (75000, 5).
# done dimension:  5 time:  419.3559031486511
# shape of x (75000, 10).
# done dimension:  10 time:  646.2993900775909
# shape of x (75000, 25).
# done dimension:  25 time:  1523.4083271026611
# shape of x (75000, 50).
# done dimension:  50 time:  3589.93141412735

# %%
netApprox_times = [354.3781728744507, 
                   419.3559031486511, 
                   646.2993900775909, 
                   1523.4083271026611, 
                   3589.93141412735]

# %%
# create a scatter plot of dimension vs runtime.
plt.figure(figsize=(9, 7))
plt.scatter(dimension_list, NetApprox_times, marker='o', color='black', s=56)

plt.xlabel('dimension', fontsize=26)
plt.ylabel('times (in seconds)', fontsize=26)

plt.title('NetApprox Runtime (N=500)', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
# plt.savefig('NetApprox_runtimevdimension.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Gurobi Implementation [FH23]

# %%
model_objbound_frac, model_objval_frac, weights_frac, model_frac = algorithms.solve_regression_fractional(x,y, intercept=True,time_limit=30, warm_start=None, verbose=True,
                               greater_one_constraint=False, pairs=None)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2617160
# Academic license - for non-commercial use only - expires 2026-02-01
# set residual constraints
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 30
# start solving
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 21.0.1 21A344)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  30
# NonConvex  2
#
# Optimize a model with 33000 rows, 16502 columns and 33000 nonzeros
# Model fingerprint: 0x656fcfd8
# Model has 3 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e-08, 2e+01]
#   QLMatrix range   [3e-06, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 33000 rows and 0 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Found heuristic solution: objective -0.0000000
# Presolve removed 33000 rows and 0 columns
# Presolve time: 0.06s
# Presolved: 132003 rows, 49503 columns, 412500 nonzeros
# Presolved model has 33000 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 49503 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 9411.2573716
#
# Interrupt request received
#
# Deterministic concurrent LP optimizer: primal and dual simplex (primal and dual model)
# Showing primal log only...
#
#
#
# Root relaxation: interrupted, 0 iterations, 0.11 seconds (0.01 work units)
#
# Explored 1 nodes (0 simplex iterations) in 7.41 seconds (0.59 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 9411.26 -0
#
# Solve interrupted
# Best objective 9.411257371618e+03, best bound 1.650000000000e+04, gap 75.3220%

# %%
N = 5000
gurobi_weights = np.array([w.X for w in weights_frac])
print(f'size of set to flip the sign: {N - sum(gurobi_weights)}')
# Out:
# size of set to flip the sign: 1934.738105588308

# %%
model_objbound, model_objval, weights, model = algorithms.solve_regression_integral(x,y, intercept=True,time_limit=30, warm_start=gurobi_weights, verbose=True, #beta_sign=1,
                                warm_start_ub=None, pairs = None)
# Out:
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 30
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 21.0.1 21A344)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  30
# NonConvex  2
#
# Optimize a model with 1 rows, 5051 columns and 1 nonzeros
# Model fingerprint: 0x4f29104c
# Model has 51 quadratic constraints
# Variable types: 51 continuous, 5000 integer (5000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [2e-11, 2e+01]
#   QLMatrix range   [1e-06, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Warning: Quadratic constraints contain large coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# User MIP start produced solution with objective 3065 (0.64s)
# Loaded user MIP start with objective 3065
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 3.22s
# Presolved: 510051 rows, 770051 columns, 14535000 nonzeros
# Presolved model has 510000 SOS constraint(s)
# Variable types: 510051 continuous, 260000 integer (260000 binary)
#
# Root relaxation: time limit, 0 iterations, 0.76 seconds (1.36 work units)
#
# Explored 1 nodes (0 simplex iterations) in 30.36 seconds (42.55 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 3065
#
# Time limit reached
# Best objective 3.065000000000e+03, best bound 5.000000000000e+03, gap 63.1321%

# %%
N = 500
inte_gurobi_weights = np.array([w.X for w in weights])
print(f'size of set to flip the sign: {N - sum(inte_gurobi_weights)}')
# Out:
# size of set to flip the sign: 197.0

# %% [markdown]
# ## Timed Experiment for Integral Gurobi Algorithm [FH23]

# %%
# Record runtime.
FH_times = []
FH_mis_size = []
# Set dimensions.
dimension_list = [10] # , 10, 25, 50

for elt in dimension_list:
    # Set dimensions.
    total_observations = 75000
    d = elt

    # Generate X, a d-dimensional isotropic Gaussian.
    mean = np.zeros(d)
    cov = np.identity(d)
    x = np.random.multivariate_normal(mean, cov, total_observations)

    # Generate Y, a linear combination of x with some noise.
    sigma = 1
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)
    print(f'X shape is {x.shape}, y shape is {y.shape}.' )

    # start recording time.
    start_time = time.time()
    # Note: Directly running Gurobi on the integer-constrained instance, 
    # without a warm start obtained by rounding a fractional solution, 
    # often shows significantly worse performance (section 2.1 FH23).
    model_objbound_frac, model_objval_frac, weights_frac, model_frac = algorithms.solve_regression_fractional(x,y, intercept=True,time_limit=30, warm_start=None, verbose=True,
                               greater_one_constraint=False, pairs=None)
    
    weights_from_fractional_gurobi = np.array([w.X for w in weights_frac])
    model_objbound, model_objval, weights, model = algorithms.solve_regression_integral(x,y, intercept=True,time_limit=30, warm_start=weights_from_fractional_gurobi, verbose=True, #beta_sign=1,
                                warm_start_ub=None, pairs = None)
    # end recording time.
    end_time = time.time()
    print("done dimension: ", d)

    FH_times.append(end_time - start_time)
    N = 75000
    gurobi_weights = np.array([w.X for w in weights])
    print(f'size of set to flip the sign: {N - sum(gurobi_weights)}')
    FH_mis_size.append(N - sum(gurobi_weights))
# Out:
# X shape is (75000, 10), y shape is (75000,).
# set residual constraints
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 30
# start solving
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 21.0.1 21A344)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  30
# NonConvex  2
#
# Optimize a model with 150000 rows, 75010 columns and 150000 nonzeros
# Model fingerprint: 0x3714cbc2
# Model has 11 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e-12, 3e+01]
#   QLMatrix range   [9e-07, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Warning: Quadratic constraints contain large coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 150000 rows and 0 columns
#
# Continuous model is non-convex -- solving as a MIP
#
# Found heuristic solution: objective -0.0000000
# Presolve removed 150000 rows and 0 columns
# Presolve time: 2.16s
# Presolved: 3000011 rows, 825011 columns, 15075000 nonzeros
# Presolved model has 750000 bilinear constraint(s)
# Warning: Model contains variables with very large bounds participating
#          in product terms.
#          Presolve was not able to compute smaller bounds for these variables.
#          Consider bounding these variables or reformulating the model.
#
# Variable types: 825011 continuous, 0 integer (0 binary)
# Performing another presolve...
# Presolve removed 3000000 rows and 1 columns
# Presolve time: 3.83s
# Found heuristic solution: objective 42371.838283
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
#
#
# Root relaxation: time limit, 0 iterations, 2.16 seconds (0.56 work units)
#
# Explored 1 nodes (0 simplex iterations) in 3888.46 seconds (28.62 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 2: 42371.8 -0
#
# Time limit reached
# Best objective 4.237183828338e+04, best bound 7.500000000000e+04, gap 77.0044%
# Set parameter NonConvex to value 2
# Set parameter TimeLimit to value 30
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 21.0.1 21A344)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Non-default parameters:
# TimeLimit  30
# NonConvex  2
#
# Optimize a model with 1 rows, 75011 columns and 1 nonzeros
# Model fingerprint: 0x9977a949
# Model has 11 quadratic constraints
# Variable types: 11 continuous, 75000 integer (75000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [1e-12, 3e+01]
#   QLMatrix range   [9e-07, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Warning: Quadratic constraints contain large coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
#
# User MIP start produced solution with objective 42372 (0.39s)
# Loaded user MIP start with objective 42372
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 2.33s
# Presolved: 1650011 rows, 2550011 columns, 14025000 nonzeros
# Presolved model has 1650000 SOS constraint(s)
# Variable types: 1650011 continuous, 900000 integer (900000 binary)
#
# Explored 1 nodes (0 simplex iterations) in 30.21 seconds (19.43 work units)
# Thread count was 10 (of 10 available processors)
#
# Solution count 1: 42372
#
# Time limit reached
# Best objective 4.237200000000e+04, best bound 7.500000000000e+04, gap 77.0037%
# done dimension:  10
# size of set to flip the sign: 32628.0

# %%
# create a scatter plot of dimension vs runtime.
plt.figure(figsize=(9, 7))
plt.scatter(dimension_list, FH_times, marker='o', color='black', s=56)

plt.xlabel('dimension', fontsize=26)
plt.ylabel('times (in seconds)', fontsize=26)

plt.title('Gurobi Implementation from FH23 Runtime (N=500)', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
# plt.savefig('Gurobi_runtimevdimension.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Timed Experiment for Greedy-1Exact [KZC21]

# %%
# store the original x and y.
orig_x = x
orig_y = y
# compute scores for initial round of the greedy algorithm.
orig_df, if_inds, if_scores, newton_inds, newton_scores = linear_regression.create_orig_df(orig_x, orig_y, lr)
# store the original indices of x and y.
orig_inds_if = if_inds
orig_inds_newton = newton_inds

# %%
# sample run of the greedy algorithm.
dropped_order, exact_changes_beta, beta_estimates_greedy = linear_regression.Run_Greedy(orig_x, orig_y, orig_inds_if, orig_inds_newton, lr, method='1Exact')

print("dropped order: \n", dropped_order)
print("exact (greedy) beta estimates: \n", beta_estimates_greedy)
# Out:
# interation 0
# index to remove 224
# fitted beta1: 1.0176816924587433
# interation 1
# index to remove 150
# fitted beta1: 1.0047097862054528
# interation 2
# index to remove 69
# fitted beta1: 0.9951319360646436
# interation 3
# index to remove 94
# fitted beta1: 0.9862078155716911
# interation 4
# index to remove 207
# fitted beta1: 0.9772516059287564
# interation 5
# index to remove 10
# fitted beta1: 0.968442665421411
# interation 6
# index to remove 355
# fitted beta1: 0.9595843487684628
# interation 7
# index to remove 124
# fitted beta1: 0.95077039640898
# interation 8
# index to remove 369
# fitted beta1: 0.9432472408408334
# interation 9
# index to remove 5
# fitted beta1: 0.9366890368143683
# interation 10
# index to remove 180
# fitted beta1: 0.9300164247537768
# interation 11
# index to remove 113
# fitted beta1: 0.92320253921003
# interation 12
# index to remove 216
# fitted beta1: 0.9165737251035068
# interation 13
# index to remove 370
# fitted beta1: 0.9105592788565495
# interation 14
# index to remove 312
# fitted beta1: 0.9044967995888927
# interation 15
# index to remove 231
# fitted beta1: 0.8984805606374435
# interation 16
# index to remove 274
# fitted beta1: 0.892475176811419
# interation 17
# index to remove 42
# fitted beta1: 0.8868409911634767
# interation 18
# index to remove 128
# fitted beta1: 0.8810563300331089
# interation 19
# index to remove 106
# fitted beta1: 0.8753449039125341
# interation 20
# index to remove 35
# fitted beta1: 0.8690101027042292
# interation 21
# index to remove 266
# fitted beta1: 0.8629506813996634
# interation 22
# index to remove 398
# fitted beta1: 0.8570989103717241
# interation 23
# index to remove 236
# fitted beta1: 0.8512727529814327
# interation 24
# index to remove 458
# fitted beta1: 0.8451506677483942
# interation 25
# index to remove 116
# fitted beta1: 0.8386799067906006
# interation 26
# index to remove 254
# fitted beta1: 0.8321905973235713
# interation 27
# index to remove 91
# fitted beta1: 0.8254442980529004
# interation 28
# index to remove 120
# fitted beta1: 0.8187336294151305
# interation 29
# index to remove 129
# fitted beta1: 0.8126362700374783
# interation 30
# index to remove 8
# fitted beta1: 0.8064891610437888
# interation 31
# index to remove 436
# fitted beta1: 0.8000177241177211
# interation 32
# index to remove 287
# fitted beta1: 0.793338354838561
# interation 33
# index to remove 436
# fitted beta1: 0.7868999552075981
# interation 34
# index to remove 102
# fitted beta1: 0.7804136851571133
# interation 35
# index to remove 427
# fitted beta1: 0.7738921404681525
# interation 36
# index to remove 290
# fitted beta1: 0.767855547377073
# interation 37
# index to remove 151
# fitted beta1: 0.7617270953813473
# interation 38
# index to remove 10
# fitted beta1: 0.7553262518600337
# interation 39
# index to remove 347
# fitted beta1: 0.7488130083036078
# interation 40
# index to remove 173
# fitted beta1: 0.7427602733538745
# interation 41
# index to remove 67
# fitted beta1: 0.7372774927556007
# interation 42
# index to remove 275
# fitted beta1: 0.7312429557572071
# interation 43
# index to remove 42
# fitted beta1: 0.7254798867757236
# interation 44
# index to remove 38
# fitted beta1: 0.7199481595947405
# interation 45
# index to remove 402
# fitted beta1: 0.7141079733051048
# interation 46
# index to remove 61
# fitted beta1: 0.708313484575982
# interation 47
# index to remove 244
# fitted beta1: 0.7026877964238419
# interation 48
# index to remove 375
# fitted beta1: 0.6966760887861201
# interation 49
# index to remove 223
# fitted beta1: 0.6908870427381427
# interation 50
# index to remove 63
# fitted beta1: 0.6846736612266205
# interation 51
# index to remove 264
# fitted beta1: 0.6784161285324123
# interation 52
# index to remove 369
# fitted beta1: 0.6722335514430905
# interation 53
# index to remove 302
# fitted beta1: 0.6659718497133691
# interation 54
# index to remove 206
# fitted beta1: 0.6598015146349548
# interation 55
# index to remove 426
# fitted beta1: 0.6525432900066368
# interation 56
# index to remove 226
# fitted beta1: 0.6460283055421486
# interation 57
# index to remove 375
# fitted beta1: 0.6394484624785266
# interation 58
# index to remove 70
# fitted beta1: 0.6325435291890462
# interation 59
# index to remove 432
# fitted beta1: 0.6259356149641244
# interation 60
# index to remove 108
# fitted beta1: 0.6191896200554335
# interation 61
# index to remove 86
# fitted beta1: 0.6126196276694523
# interation 62
# index to remove 310
# fitted beta1: 0.6059949155467184
# interation 63
# index to remove 300
# fitted beta1: 0.5999839214437992
# interation 64
# index to remove 210
# fitted beta1: 0.5934471257529309
# interation 65
# index to remove 350
# fitted beta1: 0.5865915674505953
# interation 66
# index to remove 125
# fitted beta1: 0.5794731607299074
# interation 67
# index to remove 358
# fitted beta1: 0.5725297133634268
# interation 68
# index to remove 84
# fitted beta1: 0.565266236522978
# interation 69
# index to remove 94
# fitted beta1: 0.5584950603720609
# interation 70
# index to remove 182
# fitted beta1: 0.5513477068416897
# interation 71
# index to remove 203
# fitted beta1: 0.5438808063286072
# interation 72
# index to remove 62
# fitted beta1: 0.5368163427762309
# interation 73
# index to remove 333
# fitted beta1: 0.5294425602582004
# interation 74
# index to remove 118
# fitted beta1: 0.521697212517009
# interation 75
# index to remove 191
# fitted beta1: 0.5142921994439646
# interation 76
# index to remove 358
# fitted beta1: 0.5070829945514096
# interation 77
# index to remove 130
# fitted beta1: 0.5006861575988698
# interation 78
# index to remove 192
# fitted beta1: 0.4939382305668353
# interation 79
# index to remove 185
# fitted beta1: 0.48775625702842007
# interation 80
# index to remove 230
# fitted beta1: 0.4815032822518479
# interation 81
# index to remove 29
# fitted beta1: 0.47529865653515563
# interation 82
# index to remove 139
# fitted beta1: 0.4690449293701152
# interation 83
# index to remove 390
# fitted beta1: 0.4625552632903598
# interation 84
# index to remove 137
# fitted beta1: 0.4563704844621945
# interation 85
# index to remove 342
# fitted beta1: 0.45042378428922714
# interation 86
# index to remove 289
# fitted beta1: 0.4443078906812311
# interation 87
# index to remove 236
# fitted beta1: 0.43819714655559894
# interation 88
# index to remove 371
# fitted beta1: 0.4317860164978901
# interation 89
# index to remove 52
# fitted beta1: 0.4251400530412557
# interation 90
# index to remove 136
# fitted beta1: 0.4183023301914478
# interation 91
# index to remove 160
# fitted beta1: 0.41164644964637637
# interation 92
# index to remove 337
# fitted beta1: 0.4038255770078256
# interation 93
# index to remove 102
# fitted beta1: 0.3970521277728357
# interation 94
# index to remove 199
# fitted beta1: 0.3905926309241562
# interation 95
# index to remove 50
# fitted beta1: 0.3838337945843839
# interation 96
# index to remove 286
# fitted beta1: 0.377311311773161
# interation 97
# index to remove 57
# fitted beta1: 0.37097874264310204
# interation 98
# index to remove 213
# fitted beta1: 0.3647632695298384
# interation 99
# index to remove 82
# fitted beta1: 0.35884216722184753
# interation 100
# index to remove 173
# fitted beta1: 0.35249990018207883
# interation 101
# index to remove 54
# fitted beta1: 0.34630431016751045
# interation 102
# index to remove 342
# fitted beta1: 0.3398260982510435
# interation 103
# index to remove 339
# fitted beta1: 0.33358633714963215
# interation 104
# index to remove 148
# fitted beta1: 0.3265282073476956
# interation 105
# index to remove 39
# fitted beta1: 0.31961927444720595
# interation 106
# index to remove 170
# fitted beta1: 0.3116357774933525
# interation 107
# index to remove 287
# fitted beta1: 0.30539831779768656
# interation 108
# index to remove 215
# fitted beta1: 0.29865693900926704
# interation 109
# index to remove 324
# fitted beta1: 0.2919026912991849
# interation 110
# index to remove 311
# fitted beta1: 0.2852083226904042
# interation 111
# index to remove 198
# fitted beta1: 0.2780933771785664
# interation 112
# index to remove 177
# fitted beta1: 0.27152512068944323
# interation 113
# index to remove 97
# fitted beta1: 0.2640727329424099
# interation 114
# index to remove 101
# fitted beta1: 0.2576289972842986
# interation 115
# index to remove 110
# fitted beta1: 0.2511005803861602
# interation 116
# index to remove 16
# fitted beta1: 0.24273544214483542
# interation 117
# index to remove 259
# fitted beta1: 0.23549020229526924
# interation 118
# index to remove 98
# fitted beta1: 0.2275172575855393
# interation 119
# index to remove 213
# fitted beta1: 0.21896219364958378
# interation 120
# index to remove 256
# fitted beta1: 0.21062266290471623
# interation 121
# index to remove 75
# fitted beta1: 0.20274034377291078
# interation 122
# index to remove 32
# fitted beta1: 0.1937985064737354
# interation 123
# index to remove 164
# fitted beta1: 0.18531176547459108
# interation 124
# index to remove 222
# fitted beta1: 0.17726701306238069
# interation 125
# index to remove 9
# fitted beta1: 0.16722124323241933
# interation 126
# index to remove 139
# fitted beta1: 0.15762063858050976
# interation 127
# index to remove 353
# fitted beta1: 0.14897837262263935
# interation 128
# index to remove 40
# fitted beta1: 0.14031502344707789
# interation 129
# index to remove 328
# fitted beta1: 0.1314777319297676
# interation 130
# index to remove 121
# fitted beta1: 0.12261522298199234
# interation 131
# index to remove 6
# fitted beta1: 0.11356825143970234
# interation 132
# index to remove 206
# fitted beta1: 0.10443361879887825
# interation 133
# index to remove 38
# fitted beta1: 0.09604709393612215
# interation 134
# index to remove 174
# fitted beta1: 0.08637545947596226
# interation 135
# index to remove 80
# fitted beta1: 0.07611313827079141
# interation 136
# index to remove 91
# fitted beta1: 0.06591875632758476
# interation 137
# index to remove 262
# fitted beta1: 0.05569306442937816
# interation 138
# index to remove 272
# fitted beta1: 0.04530355394588226
# interation 139
# index to remove 290
# fitted beta1: 0.035325172495910384
# interation 140
# index to remove 266
# fitted beta1: 0.025253553868405
# interation 141
# index to remove 33
# fitted beta1: 0.014741652719568399
# interation 142
# index to remove 247
# fitted beta1: 0.003597149518226983
# interation 143
# index to remove 274
# fitted beta1: -0.007293129122860953
# dropped order:
#  [224, 150, 69, 94, 207, 10, 355, 124, 369, 5, 180, 113, 216, 370, 312, 231, 274, 42, 128, 106, 35, 266, 398, 236, 458, 116, 254, 91, 120, 129, 8, 436, 287, 436, 102, 427, 290, 151, 10, 347, 173, 67, 275, 42, 38, 402, 61, 244, 375, 223, 63, 264, 369, 302, 206, 426, 226, 375, 70, 432, 108, 86, 310, 300, 210, 350, 125, 358, 84, 94, 182, 203, 62, 333, 118, 191, 358, 130, 192, 185, 230, 29, 139, 390, 137, 342, 289, 236, 371, 52, 136, 160, 337, 102, 199, 50, 286, 57, 213, 82, 173, 54, 342, 339, 148, 39, 170, 287, 215, 324, 311, 198, 177, 97, 101, 110, 16, 259, 98, 213, 256, 75, 32, 164, 222, 9, 139, 353, 40, 328, 121, 6, 206, 38, 174, 80, 91, 262, 272, 290, 266, 33, 247, 274]
# exact (greedy) beta estimates:
#  [1.0176816924587433, 1.0047097862054528, 0.9951319360646436, 0.9862078155716911, 0.9772516059287564, 0.968442665421411, 0.9595843487684628, 0.95077039640898, 0.9432472408408334, 0.9366890368143683, 0.9300164247537768, 0.92320253921003, 0.9165737251035068, 0.9105592788565495, 0.9044967995888927, 0.8984805606374435, 0.892475176811419, 0.8868409911634767, 0.8810563300331089, 0.8753449039125341, 0.8690101027042292, 0.8629506813996634, 0.8570989103717241, 0.8512727529814327, 0.8451506677483942, 0.8386799067906006, 0.8321905973235713, 0.8254442980529004, 0.8187336294151305, 0.8126362700374783, 0.8064891610437888, 0.8000177241177211, 0.793338354838561, 0.7868999552075981, 0.7804136851571133, 0.7738921404681525, 0.767855547377073, 0.7617270953813473, 0.7553262518600337, 0.7488130083036078, 0.7427602733538745, 0.7372774927556007, 0.7312429557572071, 0.7254798867757236, 0.7199481595947405, 0.7141079733051048, 0.708313484575982, 0.7026877964238419, 0.6966760887861201, 0.6908870427381427, 0.6846736612266205, 0.6784161285324123, 0.6722335514430905, 0.6659718497133691, 0.6598015146349548, 0.6525432900066368, 0.6460283055421486, 0.6394484624785266, 0.6325435291890462, 0.6259356149641244, 0.6191896200554335, 0.6126196276694523, 0.6059949155467184, 0.5999839214437992, 0.5934471257529309, 0.5865915674505953, 0.5794731607299074, 0.5725297133634268, 0.565266236522978, 0.5584950603720609, 0.5513477068416897, 0.5438808063286072, 0.5368163427762309, 0.5294425602582004, 0.521697212517009, 0.5142921994439646, 0.5070829945514096, 0.5006861575988698, 0.4939382305668353, 0.48775625702842007, 0.4815032822518479, 0.47529865653515563, 0.4690449293701152, 0.4625552632903598, 0.4563704844621945, 0.45042378428922714, 0.4443078906812311, 0.43819714655559894, 0.4317860164978901, 0.4251400530412557, 0.4183023301914478, 0.41164644964637637, 0.4038255770078256, 0.3970521277728357, 0.3905926309241562, 0.3838337945843839, 0.377311311773161, 0.37097874264310204, 0.3647632695298384, 0.35884216722184753, 0.35249990018207883, 0.34630431016751045, 0.3398260982510435, 0.33358633714963215, 0.3265282073476956, 0.31961927444720595, 0.3116357774933525, 0.30539831779768656, 0.29865693900926704, 0.2919026912991849, 0.2852083226904042, 0.2780933771785664, 0.27152512068944323, 0.2640727329424099, 0.2576289972842986, 0.2511005803861602, 0.24273544214483542, 0.23549020229526924, 0.2275172575855393, 0.21896219364958378, 0.21062266290471623, 0.20274034377291078, 0.1937985064737354, 0.18531176547459108, 0.17726701306238069, 0.16722124323241933, 0.15762063858050976, 0.14897837262263935, 0.14031502344707789, 0.1314777319297676, 0.12261522298199234, 0.11356825143970234, 0.10443361879887825, 0.09604709393612215, 0.08637545947596226, 0.07611313827079141, 0.06591875632758476, 0.05569306442937816, 0.04530355394588226, 0.035325172495910384, 0.025253553868405, 0.014741652719568399, 0.003597149518226983, -0.007293129122860953]

# %%
# Record runtimes.
times = []
mis_size = []
# Set dimensions.
dimension_list = [2, 5, 10, 25, 50]

for elt in dimension_list:
    # Set dimensions.
    total_observations = 75000
    d = elt

    # Generate X, a d-dimensional isotropic Gaussian.
    mean = np.zeros(d)
    cov = np.identity(d)
    x = np.random.multivariate_normal(mean, cov, total_observations)

    # Generate Y, a linear combination of x with some noise.
    sigma = 1
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)
    print(f'X shape is {x.shape}, y shape is {y.shape}.' )

    # initialize greedy.
    # store the original x and y.
    orig_x = x
    orig_y = y
    # compute scores for initial round of the greedy algorithm.
    orig_df, if_inds, if_scores, newton_inds, newton_scores = linear_regression.create_orig_df(orig_x, orig_y, lr)
    # store the original indices of x and y.
    orig_inds_if = if_inds
    orig_inds_newton = newton_inds

    # start recording time.
    start_time = time.time()
    
    # run greedy
    dropped_order, exact_changes_beta, beta_estimates_greedy = linear_regression.Run_Greedy(orig_x, orig_y, orig_inds_if, orig_inds_newton, lr, total_observations * .01, method='IF')

    # end recording time.
    end_time = time.time()
    print("done dimension: ", d)

    times.append(end_time - start_time)
# Out:
# X shape is (75000, 2), y shape is (75000,).
# done dimension:  2
# X shape is (75000, 5), y shape is (75000,).
# done dimension:  5
# X shape is (75000, 10), y shape is (75000,).
# done dimension:  10
# X shape is (75000, 25), y shape is (75000,).
# done dimension:  25
# X shape is (75000, 50), y shape is (75000,).
# done dimension:  50

# %%
# completed experiment on N=75000.
greedy_amip_times = [27.36555290222168, 32.4331169128418, 40.62461805343628, 73.6796326637268, 120.75594282150269]
greedy_1exact_times = [26.551573991775513, 33.09503889083862, 42.473901987075806, 68.8707971572876, 130.24753403663635]

# %% [markdown]
# ## Greedy Code: Lighter Rendition.

# %%
def greedy_light(x, y, total_observations, method='IF'):
    lr = LinearRegression(x=x.T, y=y)
    lr.fit()
    beta = lr.beta[0] # pick an arbitrary dimension of beta as the QoI.
    floor_alphaN = np.floor(total_observations * .01).astype(int)
    for __ in range(floor_alphaN):
        # compute the one-step newton update to the full model for dropping the ith observation.
        if method == 'IF':
            if_scores = -lr.influence_scores()[0]
            sorted_if_scores = np.sort(if_scores)
            largest_if_score = sorted_if_scores[0]
            beta += largest_if_score
            drop_index = np.argmax(np.abs(if_scores))
        else:
            newton_scores = -lr.one_step_newton()[0]
            sorted_newton_scores = np.sort(newton_scores)
            largest_newton_score = sorted_newton_scores[0]
            beta += largest_newton_score
            drop_index = np.argmax(np.abs(newton_scores))
        
        x = np.delete(x, drop_index, axis=0)
        y = np.delete(y, drop_index)
        # update the linear regression model.
        lr = LinearRegression(x=x.T, y=y)
        lr.fit()
    return beta

# %%
# Record runtimes.
times = []
# Set dimensions.
dimension_list = [2,50]

for elt in dimension_list:
    # Set dimensions.
    total_observations = 16560
    d = elt

    # Generate X, a d-dimensional isotropic Gaussian.
    mean = np.zeros(d)
    cov = np.identity(d)
    x = np.random.multivariate_normal(mean, cov, total_observations)

    # Generate Y, a linear combination of x with some noise.
    sigma = 1
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)
    print(f'X shape is {x.shape}, y shape is {y.shape}.' )

    # start recording time.
    start_time = time.time()

    # run greedy
    greedy_beta_est = greedy_light(x, y, total_observations, method='1Exact')

    # end recording time.
    end_time = time.time()
    print(f'greedy estimate is: {greedy_beta_est}.')

    print("done dimension: ", d)

    times.append(end_time - start_time)
# Out:
# X shape is (16560, 2), y shape is (16560,).
# greedy estimate is: 0.9538000342325917.
# done dimension:  2
# X shape is (16560, 50), y shape is (16560,).
# greedy estimate is: 0.9523725786718786.
# done dimension:  50

# %%
times
# Out:
# [0.4308619499206543, 5.486117124557495]

# %%
# run full regression.
# start time.
start = time.time()
# end time
end = time.time()

# %% [markdown]
# ## Additive Approximations.

# %%
# Record runtimes.
amip_times = []
add1Exact_times = []
mis_size = []
# Set dimensions.
dimension_list = [2, 5, 10, 25, 50] # , 5, 10, 25, 50
# Maximum number of observations to remove.
alphaN = int(total_observations*0.01)

for elt in dimension_list:
    # Set dimensions.
    total_observations = 75000
    d = elt

    # Generate X, a d-dimensional isotropic Gaussian.
    mean = np.zeros(d)
    cov = np.identity(d)
    x = np.random.multivariate_normal(mean, cov, total_observations)

    # Generate Y, a linear combination of x with some noise.
    sigma = 1
    epsilon = np.random.normal(0, sigma, total_observations)
    y = []
    # take the inner product of x and beta and add epsilon.
    for i in range(total_observations):
        y.append(np.dot(x[i], np.ones(d)) + epsilon[i])
    y = np.array(y)
    print(f'X shape is {x.shape}, y shape is {y.shape}.' )
    
    lr = LinearRegression(x=x.T, y=y)
    lr.fit()
    print(
        f"Estimated beta1 with full dataset: {lr.beta[1]}\n"
    )
    
    # AMIP
    # start recording time.
    start_time = time.time()

    # compute scores.
    scores = -lr.influence_scores()[1]
    # sort.
    inds = np.argsort(scores)
    sorted_scores = scores[inds]
    sorted_if_scores = sorted_scores
    # sum top alpha N,
    sum(sorted_if_scores[:alphaN])

    # end recording time.
    end_time = time.time()

    amip_times.append(end_time - start_time)

    # Add1Exact
    # start recording time.
    start_time = time.time()
    # compute scores.
    newton_scores = -lr.one_step_newton()[1]
    # sort.
    inds = np.argsort(newton_scores)
    sorted_scores = newton_scores[inds]
    sorted_newton_scores = sorted_scores
    # sum top alpha N,
    sum(sorted_newton_scores[:alphaN])

    # end recording time.
    end_time = time.time()
    add1Exact_times.append(end_time - start_time)
    print("done dimension: ", d)
# Out:
# X shape is (75000, 2), y shape is (75000,).
# Estimated beta1 with full dataset: 0.9979153683663907
#
# done dimension:  2
# X shape is (75000, 5), y shape is (75000,).
# Estimated beta1 with full dataset: 1.0000888139898623
#
# done dimension:  5
# X shape is (75000, 10), y shape is (75000,).
# Estimated beta1 with full dataset: 0.9949862407829185
#
# done dimension:  10
# X shape is (75000, 25), y shape is (75000,).
# Estimated beta1 with full dataset: 0.9995658193113001
#
# done dimension:  25
# X shape is (75000, 50), y shape is (75000,).
# Estimated beta1 with full dataset: 1.0038740276808378
#
# done dimension:  50

# %%
# results from runtime experiments. (Feb 12th)
dimension_list = [2, 5, 10, 20, 50, 100, 200, 499]

Gr1Exact_times = [0.12188267707824707,
 0.1284773349761963,
 0.13373303413391113,
 0.1837749481201172,
 1.0087270736694336,
 3.3516287803649902,
 6.207931995391846,
 34.30080318450928]

NetApprox_times = [1.8178341388702393,
 2.352041006088257,
 3.7632241249084473,
 8.640952110290527,
 32.8718900680542,
 59.21354913711548,
 129.2376630306244,
 468.5219531059265]

FH_times = [30.0765221118927,
 30.086939096450806,
 30.109911680221558,
 30.25550889968872,
 31.0050950050354,
 33.312812089920044,
 41.234622955322266,
 101.8116717338562] # no warm start.

FH_times2 = [60.09798502922058,
 60.15341401100159,
 60.23538613319397,
 60.55925893783569,
 61.87360119819641,
 73.54208421707153,
 132.85868906974792,
 None] # warm start.
# parameter settings d=[200, 500] started run at 11:13 - crashed at 12:01.

# %%
# results from N=75000.
dimension_list = [2, 5, 10, 25, 50]

amip_times = [0.008187055587768555,
                0.009536981582641602,
                0.011567831039428711,
                0.01901698112487793,
                0.030525922775268555]

add1Exact_times = [0.008661985397338867,
                    0.010376930236816406,
                    0.013510942459106445,
                    0.055554866790771484,
                    0.04563403129577637]

# greedy_amip_times = [27.36555290222168,
#                     32.4331169128418,
#                     40.62461805343628,
#                     73.6796326637268,
#                     120.75594282150269]

# greedy_1exact_times = [26.551573991775513, 
#                        33.09503889083862, 
#                        42.473901987075806, 
#                        68.8707971572876, 
#                        130.24753403663635]

greedy_amip_times = [7.433786869049072,
 10.48315691947937,
 15.184435844421387,
 29.143096923828125,
 62.844731092453]

greedy_1exact_times = [7.706043004989624,
 11.29507303237915,
 17.11309504508972,
 34.2802209854126,
 75.54375219345093]

netApprox_times = [354.3781728744507, 
                   419.3559031486511, 
                   646.2993900775909, 
                   1523.4083271026611, 
                   3589.93141412735]

FH_times_regular = [55.08742809295654, 
                    56.79502773284912, 
                    67.78189325332642, 
                    118.3484787940979, 
                    238.20952987670898]

FH_times_warmstart = [197.29255199432373, 
                      928.0080540180206, 
                      None, None, None] # > 30 minutes (for d=10)

# %%
from matplotlib.ticker import ScalarFormatter
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# create a scatter plot of all three times against dimension.
plt.figure(figsize=(9, 7))
plt.scatter(dimension_list, amip_times, marker='o', facecolors='none', edgecolors='blue', s=89, label='AMIP')
plt.scatter(dimension_list, add1Exact_times, marker='x', color='black', s=89, label='Additive 1Exact')  
plt.scatter(dimension_list, greedy_amip_times, marker='D', facecolors='none', edgecolors='brown', s=89, label='Greedy AMIP')
plt.scatter(dimension_list, greedy_1exact_times, marker='v', facecolors='none', edgecolors='purple', s=89, label='Greedy 1Exact')  
plt.scatter(dimension_list, netApprox_times, marker='s', facecolors='none', edgecolors='green', s=89, label='NetApprox')  
plt.scatter(dimension_list, FH_times_regular, marker='^', facecolors='none', color='orange', s=89, label='FH-Gurobi')
plt.scatter(dimension_list, FH_times_warmstart, marker='h', facecolors='none', edgecolors='red', s=89, label='FH-Gurobi (warm-start)')


plt.xlabel('dimension size', fontsize=26)
plt.ylabel('time (in seconds)', fontsize=26)

# plt.title('Algorithm Runtimes (N=75000)', fontsize=26)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.legend(fontsize=16)

plt.legend(fontsize=16)

# Create inset of low-magnitude values.

ax_inset = inset_axes(plt.gca(), width="30%", height="30%", loc='upper left', bbox_to_anchor=(0.66, -0.12, 1.0, 1), bbox_transform=plt.gca().transAxes)
ax_inset.scatter(dimension_list, amip_times, marker='o', facecolors='none', edgecolors='blue', s=56, label='AMIP')
ax_inset.scatter(dimension_list, add1Exact_times, marker='x', color='black', s=56, label='Additive 1Exact')  
ax_inset.scatter(dimension_list, greedy_amip_times, marker='D', facecolors='none', edgecolors='brown', s=56, label='Greedy AMIP')
ax_inset.scatter(dimension_list, greedy_1exact_times, marker='v', facecolors='none', edgecolors='purple', s=56, label='Greedy 1Exact')  
ax_inset.scatter(dimension_list, netApprox_times, marker='s', facecolors='none', edgecolors='green', s=60, label='NetApprox')  
ax_inset.scatter(dimension_list, FH_times_regular, marker='^', facecolors='none', edgecolors='orange', s=60, label='FH-Gurobi')
ax_inset.scatter(dimension_list, FH_times_warmstart, marker='h', facecolors='none', edgecolors='red', s=60, label='FH-Gurobi (warm-start)')

ax_inset.set_xlim(0, 55)  
ax_inset.set_ylim(-10, 205)
ax_inset.tick_params(axis='both', which='major', labelsize=22) # 12
ax_inset.tick_params(axis='both', which='minor', labelsize=22)
# set ticks to scientific notation
ax_inset.yaxis.get_offset_text().set_fontsize(12)
ax_inset.xaxis.get_offset_text().set_fontsize(12)

# plt.savefig('final_runtimes_vs_dimension_shape_corrected_2.pdf', bbox_inches='tight')
plt.show()
